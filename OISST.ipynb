# %%
import xarray as xr
import matplotlib.pyplot as plt
import os
import pandas as pd
import glob
import cartopy.crs as ccrs
import cartopy.feature as cf

# 設置文件夾保存圖像
output_folder = "OISST_images"
os.makedirs(output_folder, exist_ok=True)

# %%
# 設定範圍和條件
import glob

# 將日期定義為變量
date = "20101022"
dtype = "test_data"
start_date = "2010-10-22"
end_date = "2010-10-31"

# 經緯度設定
extent = [108, 124, 10, 25]

# 設置質量等級（可以是單個值或多個值）
quality_levels = [3, 4, 5]

# %%
# 讀取數據文件並分類為白天和夜晚
data = xr.open_dataset(f"{dtype}/amsr-avhrr-v2.{date}.nc")
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, zlev: 1, lat: 720, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 2010-10-22
#   * zlev     (zlev) float32 0.0
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
# Data variables:
#     sst      (time, zlev, lat, lon) float32 ...
#     anom     (time, zlev, lat, lon) float32 ...
#     err      (time, zlev, lat, lon) float32 ...
#     ice      (time, zlev, lat, lon) float32 ...
# Attributes:
#     Conventions:    CF-1.0
#     title:          Daily-OI-V2, Final, Data (Ship, Buoy, AMSR, AVHRR: NOAA17...
#     History:        Version 2.0
#     creation_date:  2011-03-07
#     Description:    Reynolds, et al.(2007) Daily High-resolution Blended Anal...
#     Source:         NOAA/National Climatic Data Center
#     Contact:        Dick Reynolds, email: Richard.W.Reynolds@noaa.gov & Chuny...
